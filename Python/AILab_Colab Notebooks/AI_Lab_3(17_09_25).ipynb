# %%
import pandas as pd

# %%
data={'Name':[None,'Malu','Golu','Dholu','Molu','Bholu'], 'Age':[25,22,30,None,42,27], 'Exp':[2,6,4,8,None,10],'Remarks':['Good','V.Good','Satisfactory','Poor','Good','Outstanding'], 'Salary':[20,None,40,50,60,80]}

# %%
data
# Out:
# {'Name': [None, 'Malu', 'Golu', 'Dholu', 'Molu', 'Bholu'],
#  'Age': [25, 22, 30, None, 42, 27],
#  'Exp': [2, 6, 4, 8, None, 10],
#  'Remarks': ['Good', 'V.Good', 'Satisfactory', 'Poor', 'Good', 'Outstanding'],
#  'Salary': [20, None, 40, 50, 60, 80]}

# %%
x = pd.DataFrame(data)

# %%
x.isnull()
# Out:
#     Name    Age    Exp  Remarks  Salary
# 0   True  False  False    False   False
# 1  False  False  False    False    True
# 2  False  False  False    False   False
# 3  False   True  False    False   False
# 4  False  False   True    False   False
# 5  False  False  False    False   False

# %%
x.isnull().sum()
# Out:
# Name       1
# Age        1
# Exp        1
# Remarks    0
# Salary     1
# dtype: int64

# %%
df_fill=x.fillna({'Salary':x['Salary'].mean(),
                  'Name':'chotu'})
df_fill
# Out:
#     Name   Age   Exp       Remarks  Salary
# 0  chotu  25.0   2.0          Good    20.0
# 1   Malu  22.0   6.0        V.Good    50.0
# 2   Golu  30.0   4.0  Satisfactory    40.0
# 3  Dholu   NaN   8.0          Poor    50.0
# 4   Molu  42.0   NaN          Good    60.0
# 5  Bholu  27.0  10.0   Outstanding    80.0

# %%
x.head(3)
# Out:
#    Name   Age  Exp       Remarks  Salary
# 0  None  25.0  2.0          Good    20.0
# 1  Malu  22.0  6.0        V.Good     NaN
# 2  Golu  30.0  4.0  Satisfactory    40.0

# %%
x.describe()
# Out:
#              Age        Exp    Salary
# count   5.000000   5.000000   5.00000
# mean   29.200000   6.000000  50.00000
# std     7.726578   3.162278  22.36068
# min    22.000000   2.000000  20.00000
# 25%    25.000000   4.000000  40.00000
# 50%    27.000000   6.000000  50.00000
# 75%    30.000000   8.000000  60.00000
# max    42.000000  10.000000  80.00000

# %%
import seaborn as sb
sb.boxplot(data)
# Out:
# <Axes: >

# %%
sb.scatterplot(data)
# Out:
# <Axes: >

# %%
sb.pairplot(x)
